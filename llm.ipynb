# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswin-k61/NLP_Repo/blob/main/llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers accelerate

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='google/flan-t5-small',max_new_tokens=100)
print("Model loaded successfully")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ...

# %%
def ask_llm(question):
  response = generator(question)
  return response[0]["generated_text"]

question = "Explain machine learning in simple words."
answer = ask_llm(question)

print("Question:", question)
print("Answer:", answer)
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Question: Explain machine learning in simple words.
# Answer: Explain machine learning in simple words.nt functions and models created while we move machinery easily around other humans before getting away due to high machines speeds the rest in order may affect we may increase the cries back but are generally very easy machines have an active ability at working as well for this kind. Also thats often about the things how different or much information. Machine tools to process other different machinery could improve as more algorithms learn how, with different machinery as well

# %%
#small Chatbot
while True:
  user_input=input("You: ")

  if user_input.lower()=='exit':
    print("Goodbye")
    break
  response =ask_llm(user_input)
  print("Chatbot:",response)
# Out:
# You: hi
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot: himmelle anduz hieb, young buddimo. Hi and alltus lamebham: wox'siytm! good luck to usulvi, are you having tea day. the whole class for next 10 min?! it? yeah really well but for an out
# You: machine learning
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
generator=pipeline("text-generation",model="gpt2")
response=generator("Artificial Intelligence is",max_length=20)
print(response[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...

# %%
def ask_llm2(question):
  response = generator(question)
  return response[0]["generated_text"]

# %%
while True:
  user_input=input("You: ")

  if user_input.lower()=='exit':
    print("Goodbye")
    break
  response =ask_llm2(user_input)
  print("Chatbot:",response)
# Out:
# You: hi
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot: hi.
#
# "It's difficult to understand how you can say this without knowing what kind of woman you are," he told me. "You're living in the past. You look at people, you read your paper, and you don't know what they're talking about. You don't know what they're doing. You don't know how to deal with them. So you're doing what you have to do to deal with them. And you're doing what you have to do to deal with the world.
#
# "You're not looking to be in a position to do things because I don't want to be a part of this. I have to take care of my own life."
#
# ...

# %%
# !pip install --upgrade transformers sentencepiece

# %%
# !pip uninstall transformers -y
# !pip uninstall tokenizers -y
# !pip uninstall sentencepiece -y
# Out:
# Found existing installation: transformers 5.7.0
# Uninstalling transformers-5.7.0:
#   Successfully uninstalled transformers-5.7.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: sentencepiece 0.2.1
# Uninstalling sentencepiece-0.2.1:
#   Successfully uninstalled sentencepiece-0.2.1

# %%
# !pip install transformers==4.40.0 sentencepiece tokenizers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 72.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 25.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.4.1 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.40.0 which is incompatible.
# ...

# %%
from transformers import pipeline

en_to_ml = pipeline(
    "translation_en_to_ml",
    model="Helsinki-NLP/opus-mt-en-ml"
)

ml_to_en = pipeline(
    "translation_ml_to_en",
    model="Helsinki-NLP/opus-mt-ml-en"
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/818k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]

# %%
summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn"
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
text = "Artificial Intelligence is transforming industries by enabling machines to learn from data."

summary = summarizer(text, max_length=50, min_length=10, do_sample=False)
print(summary[0]['summary_text'])

translated = en_to_ml(summary[0]['summary_text'])
print(translated[0]['translation_text'])
# Out:
# Your max_length is set to 50, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
# Artificial Intelligence is transforming industries by enabling machines to learn from data.
# ജ്യോതിശ്ശാസ് ത്രപരമായ ഇന്റലിജൻസ് ഡാറ്റാബേസിൽ നിന്ന് പഠിക്കാൻ യന്ത്രങ്ങളെ പ്രാപ് തമാക്കുന്നത് ഇന്റലിജൻസ് ആണ് .

# %%
print("AI Chatbot (Summarize + Translate)")
print("Commands:")
print("1. summarize: <text>")
print("2. translate en to ml: <text>")
print("3. summarize ml: <text>")
print("Type 'exit' to quit\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    # 🔹 Summarize English
    elif user_input.lower().startswith("summarize:"):
        text = user_input[len("summarize:"):]

        summary = summarizer(text, max_length=50, min_length=10, do_sample=False)
        print("Bot:", summary[0]['summary_text'])

    # 🔹 Translate English → Malayalam
    elif user_input.lower().startswith("translate en to ml:"):
        text = user_input[len("translate en to ml:"):]

        translated = en_to_ml(text)
        print("Bot:", translated[0]['translation_text'])

    # 🔹 Malayalam → Summarize → Malayalam
    elif user_input.lower().startswith("summarize ml:"):
        text = user_input[len("summarize ml:"):]

        # Step 1: ML → EN
        english = ml_to_en(text)[0]['translation_text']

        # Step 2: Summarize
        summary = summarizer(english, max_length=50, min_length=10, do_sample=False)[0]['summary_text']

        # Step 3: EN → ML
        final = en_to_ml(summary)[0]['translation_text']

        print("Bot:", final)

    else:
        print("Bot: Invalid command")
# Out:
# AI Chatbot (Summarize + Translate)
# Commands:
# 1. summarize: <text>
# 2. translate en to ml: <text>
# 3. summarize ml: <text>
# Type 'exit' to quit
#
# You: summarize:artificial intelligence
# Your max_length is set to 50, but your input_length is only 4. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Bot: CNN.com will feature iReporter photos in a weekly Travel Snapshots gallery. Please submit your best shots of New York for next week. Visit CNN.com/Travel next Wednesday for a new gallery of snapshots.
# ...
